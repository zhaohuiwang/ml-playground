# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
wine_data = datasets.load_wine(as_frame=True)
df = wine_data.data
print(df.shape)
df
# Out:
# (178, 13)
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
std_scaler = StandardScaler()
scaled_df = std_scaler.fit_transform(df)
scaled_df
# Out:
# array([[ 1.51861254, -0.5622498 ,  0.23205254, ...,  0.36217728,
#          1.84791957,  1.01300893],
#        [ 0.24628963, -0.49941338, -0.82799632, ...,  0.40605066,
#          1.1134493 ,  0.96524152],
#        [ 0.19687903,  0.02123125,  1.10933436, ...,  0.31830389,
#          0.78858745,  1.39514818],
#        ...,
#        [ 0.33275817,  1.74474449, -0.38935541, ..., -1.61212515,
#         -1.48544548,  0.28057537],
#        [ 0.20923168,  0.22769377,  0.01273209, ..., -1.56825176,
#         -1.40069891,  0.29649784],
#        [ 1.39508604,  1.58316512,  1.36520822, ..., -1.52437837,
#         -1.42894777, -0.59516041]])

# %%
pca = PCA(n_components=3)
pca.fit_transform(scaled_df)
# Out:
# array([[ 3.31675081e+00,  1.44346263e+00, -1.65739045e-01],
#        [ 2.20946492e+00, -3.33392887e-01, -2.02645737e+00],
#        [ 2.51674015e+00,  1.03115130e+00,  9.82818670e-01],
#        [ 3.75706561e+00,  2.75637191e+00, -1.76191842e-01],
#        [ 1.00890849e+00,  8.69830821e-01,  2.02668822e+00],
#        [ 3.05025392e+00,  2.12240111e+00, -6.29395827e-01],
#        [ 2.44908967e+00,  1.17485013e+00, -9.77094891e-01],
#        [ 2.05943687e+00,  1.60896307e+00,  1.46281883e-01],
#        [ 2.51087430e+00,  9.18070957e-01, -1.77096903e+00],
#        [ 2.75362819e+00,  7.89437674e-01, -9.84247490e-01],
#        [ 3.47973668e+00,  1.30233324e+00, -4.22735217e-01],
#        [ 1.75475290e+00,  6.11977229e-01, -1.19087832e+00],
#        [ 2.11346234e+00,  6.75706339e-01, -8.65086426e-01],
#        [ 3.45815682e+00,  1.13062988e+00, -1.20427635e+00],
#        [ 4.31278391e+00,  2.09597558e+00, -1.26391275e+00],
#        [ 2.30518820e+00,  1.66255173e+00,  2.17902616e-01],
# ...

# %%
print(pca.components_)
print(sum(pca.explained_variance_ratio_))
# Out:
# [[ 0.1443294  -0.24518758 -0.00205106 -0.23932041  0.14199204  0.39466085
#    0.4229343  -0.2985331   0.31342949 -0.0886167   0.29671456  0.37616741
#    0.28675223]
#  [ 0.48365155  0.22493093  0.31606881 -0.0105905   0.299634    0.06503951
#   -0.00335981  0.02877949  0.03930172  0.52999567 -0.27923515 -0.16449619
#    0.36490283]
#  [-0.20738262  0.08901289  0.6262239   0.61208035  0.13075693  0.14617896
#    0.1506819   0.17036816  0.14945431 -0.13730621  0.08522192  0.16600459
#   -0.12674592]]
# 0.6652996889318523

# %%
pca = PCA()
pca.fit(scaled_df)
exp_var_cumul = np.cumsum(pca.explained_variance_ratio_)
exp_var_cumul = np.insert(exp_var_cumul, 0, [0])

# %%
plt.figure(figsize=(4,2),dpi=150)
plt.grid()
plt.plot(range(len(exp_var_cumul)), exp_var_cumul,  marker='o')
plt.xlabel('n_components')
plt.ylabel('Explained variance ratio')
plt.title('n_components vs. Explained Variance Ratio')
plt.show()

# %%
# To manually compute eigenvectors and eigenvalues using numpy APIs 
data = datasets.load_wine()
features = data["data"]
labels = data["target"]

scaled_df = std_scaler.fit_transform(features)

# using numpy.cov() to calculate covariance matrix, note: 
cov_matrix = np.cov(scaled_df.T)
# Compute the eigenvalues and right eigenvectors 
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)
# compute explained ratio
explained_variance_ratio = np.cumsum(eigenvalues)/np.sum(eigenvalues)

# Verify eigenvalues and eigenvectors satisfy: A ⋅ v = λ ⋅ v
for i in range(len(eigenvalues)):
    left_side = np.dot(cov_matrix, eigenvectors[:, i])  # A ⋅ v
    right_side = eigenvalues[i] * eigenvectors[:, i]  # λ ⋅ v
    
    print(f"Eigenvalue {i + 1}:\n"
          f"Left side (A ⋅ v): {left_side}\n"
          f"Right side (λ ⋅ v): {right_side}\n")
    
    # show the first three only
    if i > 1:
        break
# Out:
# Eigenvalue 1:
# Left side (A ⋅ v): [-0.68302977  1.16033477  0.00970652  1.13256874 -0.67196839 -1.86770758
#  -2.0015099   1.4127891  -1.4832853   0.41937297 -1.40418297 -1.78018856
#  -1.35703684]
# Right side (λ ⋅ v): [-0.68302977  1.16033477  0.00970652  1.13256874 -0.67196839 -1.86770758
#  -2.0015099   1.4127891  -1.4832853   0.41937297 -1.40418297 -1.78018856
#  -1.35703684]
#
# Eigenvalue 2:
# Left side (A ⋅ v): [ 1.21448818  0.56481978  0.79367437 -0.02659361  0.75240523  0.16331948
#  -0.00843676  0.07226762  0.09868981  1.33086202 -0.70118205 -0.41306325
#   0.91630054]
# Right side (λ ⋅ v): [ 1.21448818  0.56481978  0.79367437 -0.02659361  0.75240523  0.16331948
#  -0.00843676  0.07226762  0.09868981  1.33086202 -0.70118205 -0.41306325
#   0.91630054]
#
# Eigenvalue 3:
# Left side (A ⋅ v): [-0.30158449  0.12944627  0.91068102  0.89011287  0.19015221  0.21257957
#   0.21912793  0.24775651  0.21734271 -0.19967644  0.12393329  0.24141082
#  -0.18431922]
# ...

# %%
explained_variance_ratio = np.cumsum(eigenvalues)/np.sum(eigenvalues)

# %% [markdown]
# ### The Magic of Principal Component Analysis through Image Compression

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.image import imread
import numpy as np
from sklearn.decomposition import PCA, IncrementalPCA

pca = PCA()

# %%
image_raw = imread("../../data/images/dragonfly.jpg")
print(image_raw.shape)

plt.figure(figsize=[12,8])
plt.imshow(image_raw)
# Out:
# (3264, 4928, 3)

# %%
# Show the new shape of the image
print(f"the raw image dimension: \t{image_raw.shape}")
image_sum = image_raw.sum(axis=2)
# sum along the third axis with RGB values. The result is one dimension less.
print(f"the modified image dimension: \t{image_sum.shape}")

# rescale the value (min-max rescale). 0.0 = White, 1.0 = Black.
image_bw = (image_sum-image_sum.min())/(image_sum.max()--image_sum.min())
print(f"Value range \t{image_bw.min():.4f} - {image_bw.max():.4f}")
# Out:
# the raw image dimension: 	(3264, 4928, 3)
# the modified image dimension: 	(3264, 4928)
# value range 	0.0000 - 0.9149
# /tmp/ipykernel_427286/146702998.py:8: RuntimeWarning: overflow encountered in scalar negative
#   image_bw = (image_sum-image_sum.min())/(image_sum.max()--image_sum.min())
# /tmp/ipykernel_427286/146702998.py:8: RuntimeWarning: overflow encountered in scalar subtract
#   image_bw = (image_sum-image_sum.min())/(image_sum.max()--image_sum.min())

# %%
pca.fit(image_bw)

# Getting the cumulative variance
var_cumu = np.cumsum(pca.explained_variance_ratio_)*100

# How many PCs explain 95% of the variance?
k = np.argmax(var_cumu>95)
print("Number of components explaining 95% variance: "+ str(k))
#print("\n")

plt.figure(figsize=[10,5])
plt.title('Cumulative Explained Variance explained by component')
plt.ylabel('Cumulative Explained variance (%)')
plt.xlabel('Principal components')
plt.axvline(x=k, color="k", linestyle="--")
plt.axhline(y=95, color="r", linestyle="--")
ax = plt.plot(var_cumu)
# Out:
# Number of components explaining 95% variance: 25

# %%
# reduce the dimensionality with PCA and compare the image of selected dimensions
def plot_at_k(k):
    ipca = IncrementalPCA(n_components=k)
    # IncrementalPCA divides data into batches instead to perform PCA, for memory efficiency
    image_recon = ipca.inverse_transform(ipca.fit_transform(image_bw))
    plt.imshow(image_recon,cmap = plt.cm.gray)

ks = [10, 25, 50, 100, 150, 250]

plt.figure(figsize=[15,9])

for i in range(len(ks)):
    plt.subplot(2,3,i+1)
    plot_at_k(ks[i])
    plt.title("Components: "+str(ks[i]))

plt.subplots_adjust(wspace=0.2, hspace=0.0)
plt.show()
